# %% [markdown]
# Final Project Submission
#
# Please fill out:
# * Student name: Margaret Mitey
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# MICROSOFT MOVIE CREATION
#
# INTRODUCTION
#
# Microsoft is a company that was created in 1981 by Bill Gates and Paul Allen. It is the largest vendor of computer software in the world. It is also a leading provider of cloud computer services, video games, computer and gaming hardware.
# With all its diversity across different fields. Its looking to venture into movie creation which has become a great sensation for big companies to create original video contents.
#
# Video content are films, television, music etc. These production companies provuce these contents through various stages from pre-production to post production. They include script development, market research, pitch to distributors, casting, hair & make-up, custome, buy/renting equipments and editing of content.
#
# Movies produced by big companies can reach the global market because the profit of each movies that they sell go into the production budget. The production budget caters for evertything in the movie.
#
# It is important to identify a niche to which type of content should be created. The best known companies produce a specific type of content. This enables the company to perfect that area as opposed to having a general portfolio.
# It is important to do research into the companies that are there and what they focus on and if there are gaps that microsoft can fill.
#
# Since it is a new area for microsoft to venture into. It is essential for them to have key persinnel to start of with. THey are: Development executive- for creating good scripts,
# Production supervisor - to ensure stick to schedule and budget,
# Post-production supervisor - for editing the content and ensure deadlines are met and
# Head of sales and distribution - for distribution of the produced content.
#
# PROBLEM STATEMENT
# Microsoft has been the leading computer software distributors in the world. Over the years it has ventured into the gaming industry which can become valuable in movie creation by giving insight into video creation.
# It does not have any knowledge abbout movie creation as it is not an area they have ever ventured into before.
# It would be of great benefit if Microsoft would be able to know what it entails in terms of the production company, genre of film, having a star in the film, producers and the run-time of the movie to make a successful movie studio.
# The goal is to provide the CEO with tangible evidence on the type of films to create.
#
# MAIN OBJECTIVE
#
# To identify the type of movies that are doing well in the box office.
#
# SPECIFIC OBJECTIVE
# 1. Identify the top performing films in the box office.
# 2. Identify the top performing films in terms of gross income.
# 3. The relationship between studio and total revenue for film.
# 4. Identify the most used studios.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %%
bom_df = pd.read_csv('bom.movie_gross.csv.gz')
bom_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
bom_df.info
# Out:
# <bound method DataFrame.info of                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]>

# %%
bom_df.shape
# Out:
# (3387, 5)

# %%
bom_df.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
bom_df = bom_df.dropna(axis=0)
bom_df.info
# Out:
# <bound method DataFrame.info of                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross foreign_gross  year
# 0        415000000.0     652000000  2010
# 1        334200000.0     691300000  2010
# 2        296000000.0     664300000  2010
# 3        292600000.0     535700000  2010
# 4        238700000.0     513900000  2010
# ...              ...           ...   ...
# 3275          1400.0       1500000  2018
# 3286        725000.0        229000  2018
# 3309         10000.0        256000  2018
# 3342         93200.0          5200  2018
# 3353         43200.0         30000  2018
#
# [2007 rows x 5 columns]>

# %%
bom_df_without_duplicates = bom_df.drop_duplicates
bom_df
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross foreign_gross  year
# 0        415000000.0     652000000  2010
# 1        334200000.0     691300000  2010
# 2        296000000.0     664300000  2010
# 3        292600000.0     535700000  2010
# 4        238700000.0     513900000  2010
# ...              ...           ...   ...
# 3275          1400.0       1500000  2018
# 3286        725000.0        229000  2018
# 3309         10000.0        256000  2018
# 3342         93200.0          5200  2018
# 3353         43200.0         30000  2018
#
# [2007 rows x 5 columns]

# %%
income = ['domestic_gross', 'foreign_gross']
bom_df['box office'] = bom_df[income].sum(axis=1)
bom_df
# Out:
# C:\Users\Margaret Mitey\AppData\Local\Temp\ipykernel_10784\956586011.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bom_df['box office'] = bom_df[income].sum(axis=1)
# C:\Users\Margaret Mitey\AppData\Local\Temp\ipykernel_10784\956586011.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bom_df['box office'] = bom_df[income].sum(axis=1)
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross foreign_gross  year   box office
# 0        415000000.0     652000000  2010  415000000.0
# 1        334200000.0     691300000  2010  334200000.0
# 2        296000000.0     664300000  2010  296000000.0
# 3        292600000.0     535700000  2010  292600000.0
# 4        238700000.0     513900000  2010  238700000.0
# ...              ...           ...   ...          ...
# 3275          1400.0       1500000  2018       1400.0
# 3286        725000.0        229000  2018     725000.0
# 3309         10000.0        256000  2018      10000.0
# 3342         93200.0          5200  2018      93200.0
# 3353         43200.0         30000  2018      43200.0
#
# [2007 rows x 6 columns]

# %% [markdown]
# top performing films in terms of gross income >$ 100,000,000

# %%
bom_df = bom_df[bom_df['domestic_gross'] > 100000000]
bom_df
# Out:
#                                             title studio  domestic_gross  \
# 0                                     Toy Story 3     BV     415000000.0
# 1                      Alice in Wonderland (2010)     BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                       Inception     WB     292600000.0
# 4                             Shrek Forever After   P/DW     238700000.0
# ...                                           ...    ...             ...
# 3116                            Crazy Rich Asians     WB     174500000.0
# 3119                                     Creed II    MGM     115700000.0
# 3121                              The Equalizer 2   Sony     102100000.0
# 3123                                     The Mule     WB     103800000.0
# 3129                            A Wrinkle in Time     BV     100500000.0
#
#      foreign_gross  year   box office
# 0        652000000  2010  415000000.0
# 1        691300000  2010  334200000.0
# 2        664300000  2010  296000000.0
# 3        535700000  2010  292600000.0
# 4        513900000  2010  238700000.0
# ...            ...   ...          ...
# 3116      64000000  2018  174500000.0
# 3119      98300000  2018  115700000.0
# 3121      88300000  2018  102100000.0
# 3123      68700000  2018  103800000.0
# 3129      32200000  2018  100500000.0
#
# [284 rows x 6 columns]

# %% [markdown]
# Identify studios used frequently for movie production having domestic and foreign gross of > $100,000,000

# %%
bom_df.studio.value_counts()
# Out:
# BV         49
# Uni.       43
# Fox        42
# WB         41
# Sony       32
# Par.       31
# WB (NL)    16
# P/DW        8
# LGF         6
# LG/S        5
# Wein.       4
# Sum.        2
# FoxS        1
# SGem        1
# STX         1
# TriS        1
# MGM         1
# Name: studio, dtype: int64

# %% [markdown]
# Develop an Histogram to show the freuency of movies used in movie production

# %%
Fig, ax = plt.subplots(figsize = (20,8))
ax.hist(bom_df.studio, bins = 80)
ax.set_xlabel('Name of Studio')
ax.set_ylabel('Number of times the studio has been used')
ax.set_title('Studio counts')
# Out:
# Text(0.5, 1.0, 'Studio counts')

# %% [markdown]
# To know how much the movies made at the box office. The domestic and foreign revenues are added together. The variable box office was formulate

# %%
bom_df = bom_df[bom_df['box office'] > 1000000000]
bom_df
# Out:
# Empty DataFrame
# Columns: [title, studio, domestic_gross, foreign_gross, year, box office]
# Index: []

# %% [markdown]
# Plot a bar graph to show the relationship between the movie studion and how much they got at the box office

# %%
Fig, ax = plt.subplots(figsize=(15,6))
plt.bar( x= bom_df.studio, height = bom_df.box_office)
plt.xlabel('Name of studios')
plt.ylabel('box office in miliions')
plt.title('Relationship Between studio and total revenue from films')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10784\3175436673.py in <module>
#       1 Fig, ax = plt.subplots(figsize=(15,6))
# ----> 2 plt.bar( x= bom_df.studio, height = bom_df.box_office)
#       3 plt.xlabel('Name of studios')
#       4 plt.ylabel('box office in miliions')
#       5 plt.title('Relationship Between studio and total revenue from films')
#
# c:\Users\Margaret Mitey\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'box_office'

# %% [markdown]
# 2. Identifying rating of movies accoding to their titles in Imdb

# %%
imdb_df = pd.read_csv('imdb.title.basics.csv.gz')
imdb_df
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
imdb_df = imdb_df.drop_duplicates()
imdb_df
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
imdb_df = imdb_df.dropna(axis=0)
imdb_df.info
# Out:
# <bound method DataFrame.info of            tconst                                      primary_title  \
# 0       tt0063540                                          Sunghursh
# 1       tt0066787                    One Day Before the Rainy Season
# 2       tt0069049                         The Other Side of the Wind
# 4       tt0100275                           The Wandering Soap Opera
# 5       tt0111414                                        A Thin Life
# ...           ...                                                ...
# 146134  tt9916160                                         Drømmeland
# 146135  tt9916170                                      The Rehearsal
# 146136  tt9916186  Illenau - die Geschichte einer ehemaligen Heil...
# 146137  tt9916190                                          Safeguard
# 146139  tt9916538                                Kuambil Lagi Hatiku
#
#                                            original_title  start_year  \
# 0                                               Sunghursh        2013
# 1                                         Ashad Ka Ek Din        2019
# 2                              The Other Side of the Wind        2018
# 4                                   La Telenovela Errante        2017
# 5                                             A Thin Life        2018
# ...                                                   ...         ...
# 146134                                         Drømmeland        2019
# 146135                                           O Ensaio        2019
# 146136  Illenau - die Geschichte einer ehemaligen Heil...        2017
# 146137                                          Safeguard        2019
# 146139                                Kuambil Lagi Hatiku        2019
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 4                  80.0  Comedy,Drama,Fantasy
# 5                  75.0                Comedy
# ...                 ...                   ...
# 146134             72.0           Documentary
# 146135             51.0                 Drama
# 146136             84.0           Documentary
# 146137             90.0        Drama,Thriller
# 146139            123.0                 Drama
#
# [112232 rows x 6 columns]>

# %%
imdb_df = pd.read_csv('imdb.title.ratings.csv.gz')
imdb_df
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
imdb_df = imdb_df[imdb_df['averagerating'] >= 8]
imdb_df.head(20)
# Out:
#          tconst  averagerating  numvotes
# 0    tt10356526            8.3        31
# 1    tt10384606            8.9       559
# 13    tt1193623            8.0         5
# 41    tt1326743            8.4        21
# 60    tt1403990            8.5        31
# 62    tt1409015            8.2        40
# 73    tt1450750            8.6        27
# 86    tt1488109            8.2        14
# 95    tt1515069            8.3        15
# 100   tt1517605            8.7        23
# 110   tt1537385            8.0        53
# 132   tt1575538            8.2         5
# 152   tt1608246            8.0        26
# 154   tt1608345            8.4        34
# 158   tt1614963            8.1         9
# 173   tt1633334            8.4        11
# 183   tt1651906            9.2         9
# 193   tt1663202            8.0    621193
# 194   tt1664837            8.3        25
# 202   tt1671728            8.5        21

# %%
imdb_df.tconst.sort_values(ascending=False)
imdb_df.head(20)
# Out:
#          tconst  averagerating  numvotes
# 0    tt10356526            8.3        31
# 1    tt10384606            8.9       559
# 13    tt1193623            8.0         5
# 41    tt1326743            8.4        21
# 60    tt1403990            8.5        31
# 62    tt1409015            8.2        40
# 73    tt1450750            8.6        27
# 86    tt1488109            8.2        14
# 95    tt1515069            8.3        15
# 100   tt1517605            8.7        23
# 110   tt1537385            8.0        53
# 132   tt1575538            8.2         5
# 152   tt1608246            8.0        26
# 154   tt1608345            8.4        34
# 158   tt1614963            8.1         9
# 173   tt1633334            8.4        11
# 183   tt1651906            9.2         9
# 193   tt1663202            8.0    621193
# 194   tt1664837            8.3        25
# 202   tt1671728            8.5        21

# %% [markdown]
# 3. Movies that are top performing in the box office

# %%
tmdb_df = pd.read_csv('tmdb.movies.csv.gz')
tmdb_df
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
tmdb_df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]>

# %% [markdown]
# Check whether the popularity column has any mising values

# %%
tmdb_df.dropna(axis=0, inplace=True)
tmdb_df.sort_values(by= 'popularity', ascending=False)
# Out:
#        Unnamed: 0              genre_ids      id original_language  \
# 23811       23811           [12, 28, 14]  299536                en
# 11019       11019               [28, 53]  245891                en
# 23812       23812  [28, 12, 16, 878, 35]  324857                en
# 11020       11020           [28, 12, 14]  122917                en
# 5179         5179          [878, 28, 12]   24428                en
# ...           ...                    ...     ...               ...
# 13877       13877                [10749]  401741                en
# 13878       13878                  [878]  401427                en
# 13879       13879                   [35]  399054                en
# 13880       13880                     []  381154                en
# 26516       26516               [53, 27]  309885                en
#
#                                   original_title  popularity release_date  \
# 23811                     Avengers: Infinity War      80.773   2018-04-27
# 11019                                  John Wick      78.123   2014-10-24
# 23812          Spider-Man: Into the Spider-Verse      60.534   2018-12-14
# 11020  The Hobbit: The Battle of the Five Armies      53.783   2014-12-17
# 5179                                The Avengers      50.289   2012-05-04
# ...                                          ...         ...          ...
# 13877                              Crème Caramel       0.600   2014-05-20
# 13878                                      Elegy       0.600   2014-09-10
# 13879                                     Jaguar       0.600   2014-09-21
# 13880             Unleashed! A Dog Dancing Story       0.600   2014-02-13
# 26516                                 The Church       0.600   2018-10-05
#
#                                            title  vote_average  vote_count
# 23811                     Avengers: Infinity War           8.3       13948
# 11019                                  John Wick           7.2       10081
# 23812          Spider-Man: Into the Spider-Verse           8.4        4048
# 11020  The Hobbit: The Battle of the Five Armies           7.3        8392
# 5179                                The Avengers           7.6       19673
# ...                                          ...           ...         ...
# 13877                              Crème Caramel           5.0           1
# 13878                                      Elegy           5.0           1
# 13879                                     Jaguar           5.0           1
# 13880             Unleashed! A Dog Dancing Story           5.0           1
# 26516                                 The Church           0.0           1
#
# [26517 rows x 10 columns]

# %% [markdown]
# Removing the column Unnamed 0

# %%
tmdb_df = pd.read_csv('tmdb.movies.csv.gz', index_col=0)
tmdb_df.head(20)
# Out:
#                    genre_ids     id original_language  \
# 0            [12, 14, 10751]  12444                en
# 1        [14, 12, 16, 10751]  10191                en
# 2              [12, 28, 878]  10138                en
# 3            [16, 35, 10751]    862                en
# 4              [28, 878, 12]  27205                en
# 5            [12, 14, 10751]  32657                en
# 6          [28, 12, 14, 878]  19995                en
# 7            [16, 10751, 35]  10193                en
# 8            [16, 10751, 35]  20352                en
# 9   [16, 28, 35, 10751, 878]  38055                en
# 10           [16, 35, 10751]    863                en
# 11           [10751, 14, 12]  12155                en
# 12              [53, 12, 28]  27578                en
# 13               [16, 10751]  38757                en
# 14                  [27, 80]  41439                en
# 15       [12, 14, 18, 10749]  24021                en
# 16             [28, 53, 878]  20504                en
# 17            [10402, 10749]  52371                nl
# 18              [28, 18, 53]   2502                en
# 19            [18, 53, 9648]  11324                en
#
#                                        original_title  popularity  \
# 0        Harry Potter and the Deathly Hallows: Part 1      33.533
# 1                            How to Train Your Dragon      28.734
# 2                                          Iron Man 2      28.515
# 3                                           Toy Story      28.005
# 4                                           Inception      27.920
# 5   Percy Jackson & the Olympians: The Lightning T...      26.691
# 6                                              Avatar      26.526
# 7                                         Toy Story 3      24.445
# 8                                       Despicable Me      23.673
# 9                                            Megamind      22.855
# 10                                        Toy Story 2      22.698
# 11                                Alice in Wonderland      22.020
# 12                                    The Expendables      21.517
# 13                                            Tangled      21.511
# 14                                             Saw 3D      20.370
# 15                         The Twilight Saga: Eclipse      20.340
# 16                                    The Book of Eli      18.985
# 17                                         LelleBelle      18.586
# 18                               The Bourne Supremacy      18.199
# 19                                     Shutter Island      18.060
#
#    release_date                                              title  \
# 0    2010-11-19       Harry Potter and the Deathly Hallows: Part 1
# 1    2010-03-26                           How to Train Your Dragon
# 2    2010-05-07                                         Iron Man 2
# 3    1995-11-22                                          Toy Story
# 4    2010-07-16                                          Inception
# 5    2010-02-11  Percy Jackson & the Olympians: The Lightning T...
# 6    2009-12-18                                             Avatar
# 7    2010-06-17                                        Toy Story 3
# 8    2010-07-09                                      Despicable Me
# 9    2010-11-04                                           Megamind
# 10   1999-11-24                                        Toy Story 2
# 11   2010-03-05                                Alice in Wonderland
# 12   2010-08-03                                    The Expendables
# 13   2010-11-24                                            Tangled
# 14   2010-10-28                             Saw: The Final Chapter
# 15   2010-06-23                         The Twilight Saga: Eclipse
# 16   2010-01-11                                    The Book of Eli
# 17   2010-10-09                                         LelleBelle
# 18   2004-07-23                               The Bourne Supremacy
# 19   2010-02-18                                     Shutter Island
#
#     vote_average  vote_count
# 0            7.7       10788
# 1            7.7        7610
# 2            6.8       12368
# 3            7.9       10174
# 4            8.3       22186
# 5            6.1        4229
# 6            7.4       18676
# 7            7.7        8340
# 8            7.2       10057
# 9            6.8        3635
# 10           7.5        7553
# 11           6.6        8713
# 12           6.1        4647
# 13           7.5        6407
# 14           6.0        1488
# 15           6.0        4909
# 16           6.7        3495
# 17           4.5          36
# 18           7.3        4367
# 19           8.1       12625

# %%
tmdb_df = tmdb_df.sort_values(by='popularity', ascending=False)
tmdb_df.head(20)
# Out:
#                      genre_ids      id original_language  \
# 23811             [12, 28, 14]  299536                en
# 11019                 [28, 53]  245891                en
# 23812    [28, 12, 16, 878, 35]  324857                en
# 11020             [28, 12, 14]  122917                en
# 5179             [878, 28, 12]   24428                en
# 11021            [28, 878, 12]  118340                en
# 20617            [878, 28, 53]  335984                en
# 23813            [878, 28, 53]  335984                en
# 23814                     [12]  338952                en
# 23815  [10751, 16, 35, 14, 12]  404368                en
# 20618        [28, 12, 878, 18]  315635                en
# 20619             [53, 28, 80]  324552                en
# 20620            [28, 18, 878]  263115                en
# 23816        [28, 12, 878, 35]  363088                en
# 14169            [28, 12, 878]   99861                en
# 23817        [28, 12, 14, 878]  284054                en
# 23818                [878, 28]  335983                en
# 20621         [28, 12, 35, 14]  284053                en
# 23819         [28, 12, 35, 14]  284053                en
# 23820            [28, 12, 878]  424783                en
#
#                                     original_title  popularity release_date  \
# 23811                       Avengers: Infinity War      80.773   2018-04-27
# 11019                                    John Wick      78.123   2014-10-24
# 23812            Spider-Man: Into the Spider-Verse      60.534   2018-12-14
# 11020    The Hobbit: The Battle of the Five Armies      53.783   2014-12-17
# 5179                                  The Avengers      50.289   2012-05-04
# 11021                      Guardians of the Galaxy      49.606   2014-08-01
# 20617                            Blade Runner 2049      48.571   2017-10-06
# 23813                            Blade Runner 2049      48.571   2017-10-06
# 23814  Fantastic Beasts: The Crimes of Grindelwald      48.508   2018-11-16
# 23815                    Ralph Breaks the Internet      48.057   2018-11-21
# 20618                       Spider-Man: Homecoming      46.775   2017-07-07
# 20619                         John Wick: Chapter 2      45.253   2017-02-10
# 20620                                        Logan      45.000   2017-03-03
# 23816                         Ant-Man and the Wasp      44.729   2018-07-06
# 14169                      Avengers: Age of Ultron      44.383   2015-05-01
# 23817                                Black Panther      44.140   2018-02-16
# 23818                                        Venom      44.007   2018-10-05
# 20621                               Thor: Ragnarok      43.450   2017-11-03
# 23819                               Thor: Ragnarok      43.450   2017-11-03
# 23820                                    Bumblebee      43.078   2018-12-21
#
#                                              title  vote_average  vote_count
# 23811                       Avengers: Infinity War           8.3       13948
# 11019                                    John Wick           7.2       10081
# 23812            Spider-Man: Into the Spider-Verse           8.4        4048
# 11020    The Hobbit: The Battle of the Five Armies           7.3        8392
# 5179                                  The Avengers           7.6       19673
# 11021                      Guardians of the Galaxy           7.9       17958
# 20617                            Blade Runner 2049           7.4        6679
# 23813                            Blade Runner 2049           7.4        6679
# 23814  Fantastic Beasts: The Crimes of Grindelwald           6.9        4870
# 23815                    Ralph Breaks the Internet           7.2        2626
# 20618                       Spider-Man: Homecoming           7.4       11585
# 20619                         John Wick: Chapter 2           7.0        5863
# 20620                                        Logan           7.8       12330
# 23816                         Ant-Man and the Wasp           7.0        6290
# 14169                      Avengers: Age of Ultron           7.3       13457
# 23817                                Black Panther           7.4       12365
# 23818                                        Venom           6.6        6206
# 20621                               Thor: Ragnarok           7.5       11380
# 23819                               Thor: Ragnarok           7.5       11380
# 23820                                    Bumblebee           6.5        2425

# %%
tmdb_df = tmdb_df.drop_duplicates()
tmdb_df
# Out:
#                           genre_ids      id original_language  \
# 13258                          [99]  403294                en
# 26215                          [16]  559428                en
# 7103                 [35, 18, 9648]   96916                en
# 7104                           [99]   95389                en
# 7105                           [99]   91365                en
# ...                             ...     ...               ...
# 26508                          [16]  514492                en
# 24992                          [99]  543084                en
# 26057  [27, 80, 80, 80, 80, 80, 80]  570704                en
# 26113           [53, 14, 27, 10749]  297548                en
# 26516                      [53, 27]  309885                en
#
#                  original_title  popularity release_date  \
# 13258         9/11: Simulations       0.600   2014-07-04
# 26215                   Polaris       0.600   2018-11-02
# 7103             Sunset Stories       0.600   2012-03-10
# 7104     Mustafa's Sweet Dreams       0.600   2012-03-01
# 7105   How I Became An Elephant       0.600   2012-04-20
# ...                         ...         ...          ...
# 26508                      Jaws       0.600   2018-05-29
# 24992   The Biggest Little Farm       3.365   2018-09-01
# 26057         Murdery Christmas       0.840   2020-12-25
# 26113    Never Can Say Good-bye       0.702   2018-07-10
# 26516                The Church       0.600   2018-10-05
#
#                           title  vote_average  vote_count
# 13258         9/11: Simulations          10.0           1
# 26215                   Polaris          10.0           1
# 7103             Sunset Stories          10.0           1
# 7104     Mustafa's Sweet Dreams          10.0           1
# 7105   How I Became An Elephant          10.0           1
# ...                         ...           ...         ...
# 26508                      Jaws           0.0           1
# 24992   The Biggest Little Farm           0.0           5
# 26057         Murdery Christmas           0.0           1
# 26113    Never Can Say Good-bye           0.0           2
# 26516                The Church           0.0           1
#
# [25497 rows x 9 columns]

# %%
Fig, ax = plt.subplots(figsize = (30,10))
ax.hist(bom_df.studio, bins = 80)
ax.set_xlabel('original_title')
ax.set_ylabel('popularity')
ax.set_title('Most popular Movies')
# Out:
# Text(0.5, 1.0, 'Most popular Movies')

# %%
rt_df = pd.read_csv('rt.movie_info.tsv.gz', delimiter='\t')
rt_df
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %% [markdown]
# To create a dataframe that has the cucial colums for analysis
# Data cleaning to remove any row that has missing values in box_office

# %%
rt_df = rt_df.loc[:, ['id', 'synopsis', 'rating', 'genre', 'director', 'writer', 'currency', 'box_office', 'runtime', 'studio']].head(20)
rt_df
# Out:
#     id                                           synopsis rating  \
# 0    1  This gritty, fast-paced, and innovative police...      R
# 1    3  New York City, not-too-distant-future: Eric Pa...      R
# 2    5  Illeana Douglas delivers a superb performance ...      R
# 3    6  Michael Douglas runs afoul of a treacherous su...      R
# 4    7                                                NaN     NR
# 5    8  The year is 1942. As the Allies unite overseas...     PG
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 8   14  "Love Ranch" is a bittersweet love story that ...      R
# 9   15  When a diamond expedition in the Congo is lost...  PG-13
# 10  17                                                NaN    NaN
# 11  18  In 1979, Bill Viola and Frank Caliguri dreamed...     NR
# 12  19  While Microsoft may be the biggest software co...     NR
# 13  20  Rachel (Britt Ekland) is an Amish girl who rej...  PG-13
# 14  21  Old-school comic Rodney "I get no respect" Dan...      R
# 15  22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 16  23  A fictional film set in the alluring world of ...      R
# 17  24  Three young boys discover a stranded Russian s...     PG
# 18  25  From ancient Japan's most enduring tale, the e...  PG-13
# 19  26  A comic series of short vignettes build on one...      R
#
#                                                 genre             director  \
# 0                 Action and Adventure|Classics|Drama     William Friedkin
# 1                   Drama|Science Fiction and Fantasy     David Cronenberg
# 2                   Drama|Musical and Performing Arts       Allison Anders
# 3                          Drama|Mystery and Suspense       Barry Levinson
# 4                                       Drama|Romance       Rodney Bennett
# 5                               Drama|Kids and Family          Jay Russell
# 6                                              Comedy          Jake Kasdan
# 7                                               Drama         Ray Lawrence
# 8                                               Drama      Taylor Hackford
# 9   Action and Adventure|Mystery and Suspense|Scie...       Frank Marshall
# 10                                                NaN                  NaN
# 11                                        Documentary                  NaN
# 12                       Documentary|Special Interest                  NaN
# 13                              Classics|Comedy|Drama     William Friedkin
# 14                                             Comedy        Peter Baldwin
# 15                  Comedy|Drama|Mystery and Suspense  George Hickenlooper
# 16                                              Drama                  NaN
# 17                  Action and Adventure|Comedy|Drama       Rick Rosenthal
# 18  Action and Adventure|Drama|Science Fiction and...     Carl Erik Rinsch
# 19  Art House and International|Comedy|Drama|Music...         Jim Jarmusch
#
#                                                writer currency  box_office  \
# 0                                      Ernest Tidyman      NaN         NaN
# 1                        David Cronenberg|Don DeLillo        $     600,000
# 2                                      Allison Anders      NaN         NaN
# 3                     Paul Attanasio|Michael Crichton      NaN         NaN
# 4                                        Giles Cooper      NaN         NaN
# 5                                     Gail Gilchriest      NaN         NaN
# 6                                          Mike White        $  41,032,915
# 7                    Raymond Carver|Beatrix Christian        $     224,114
# 8                                       Mark Jacobson        $     134,904
# 9                                John Patrick Shanley      NaN         NaN
# 10                                                NaN      NaN         NaN
# 11                                       Robert Zullo      NaN         NaN
# 12                                                NaN      NaN         NaN
# 13        Sidney Michaels|Arnold Schulman|Norman Lear      NaN         NaN
# 14                     Rodney Dangerfield|Harry Basil      NaN         NaN
# 15                                      Norman Snider        $   1,039,869
# 16                                                NaN        $  99,165,609
# 17  Sheldon Lettich|Michael Nankin|Alan Jay Glueckman      NaN         NaN
# 18                         Chris Morgan|Hossein Amini        $  20,518,224
# 19                                       Jim Jarmusch        $   1,971,135
#
#         runtime                      studio
# 0   104 minutes                         NaN
# 1   108 minutes           Entertainment One
# 2   116 minutes                         NaN
# 3   128 minutes                         NaN
# 4   200 minutes                         NaN
# 5    95 minutes       Warner Bros. Pictures
# 6    82 minutes          Paramount Pictures
# 7   123 minutes      Sony Pictures Classics
# 8   117 minutes                         NaN
# 9   108 minutes                         NaN
# 10          NaN                         NaN
# 11          NaN  Showtime Documentary Films
# 12   90 minutes       Seventh Art Releasing
# 13   97 minutes                         NaN
# 14  106 minutes                         NaN
# 15  108 minutes                ATO Pictures
# 16  129 minutes               Sony Pictures
# 17   98 minutes                         NaN
# 18  127 minutes          Universal Pictures
# 19   96 minutes                         MGM

# %%
rt_df.info
# Out:
# <bound method DataFrame.info of     id                                           synopsis rating  \
# 0    1  This gritty, fast-paced, and innovative police...      R
# 1    3  New York City, not-too-distant-future: Eric Pa...      R
# 2    5  Illeana Douglas delivers a superb performance ...      R
# 3    6  Michael Douglas runs afoul of a treacherous su...      R
# 4    7                                                NaN     NR
# 5    8  The year is 1942. As the Allies unite overseas...     PG
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 8   14  "Love Ranch" is a bittersweet love story that ...      R
# 9   15  When a diamond expedition in the Congo is lost...  PG-13
# 10  17                                                NaN    NaN
# 11  18  In 1979, Bill Viola and Frank Caliguri dreamed...     NR
# 12  19  While Microsoft may be the biggest software co...     NR
# 13  20  Rachel (Britt Ekland) is an Amish girl who rej...  PG-13
# 14  21  Old-school comic Rodney "I get no respect" Dan...      R
# 15  22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 16  23  A fictional film set in the alluring world of ...      R
# 17  24  Three young boys discover a stranded Russian s...     PG
# 18  25  From ancient Japan's most enduring tale, the e...  PG-13
# 19  26  A comic series of short vignettes build on one...      R
#
#                                                 genre             director  \
# 0                 Action and Adventure|Classics|Drama     William Friedkin
# 1                   Drama|Science Fiction and Fantasy     David Cronenberg
# 2                   Drama|Musical and Performing Arts       Allison Anders
# 3                          Drama|Mystery and Suspense       Barry Levinson
# 4                                       Drama|Romance       Rodney Bennett
# 5                               Drama|Kids and Family          Jay Russell
# 6                                              Comedy          Jake Kasdan
# 7                                               Drama         Ray Lawrence
# 8                                               Drama      Taylor Hackford
# 9   Action and Adventure|Mystery and Suspense|Scie...       Frank Marshall
# 10                                                NaN                  NaN
# 11                                        Documentary                  NaN
# 12                       Documentary|Special Interest                  NaN
# 13                              Classics|Comedy|Drama     William Friedkin
# 14                                             Comedy        Peter Baldwin
# 15                  Comedy|Drama|Mystery and Suspense  George Hickenlooper
# 16                                              Drama                  NaN
# 17                  Action and Adventure|Comedy|Drama       Rick Rosenthal
# 18  Action and Adventure|Drama|Science Fiction and...     Carl Erik Rinsch
# 19  Art House and International|Comedy|Drama|Music...         Jim Jarmusch
#
#                                                writer currency  box_office  \
# 0                                      Ernest Tidyman      NaN         NaN
# 1                        David Cronenberg|Don DeLillo        $     600,000
# 2                                      Allison Anders      NaN         NaN
# 3                     Paul Attanasio|Michael Crichton      NaN         NaN
# 4                                        Giles Cooper      NaN         NaN
# 5                                     Gail Gilchriest      NaN         NaN
# 6                                          Mike White        $  41,032,915
# 7                    Raymond Carver|Beatrix Christian        $     224,114
# 8                                       Mark Jacobson        $     134,904
# 9                                John Patrick Shanley      NaN         NaN
# 10                                                NaN      NaN         NaN
# 11                                       Robert Zullo      NaN         NaN
# 12                                                NaN      NaN         NaN
# 13        Sidney Michaels|Arnold Schulman|Norman Lear      NaN         NaN
# 14                     Rodney Dangerfield|Harry Basil      NaN         NaN
# 15                                      Norman Snider        $   1,039,869
# 16                                                NaN        $  99,165,609
# 17  Sheldon Lettich|Michael Nankin|Alan Jay Glueckman      NaN         NaN
# 18                         Chris Morgan|Hossein Amini        $  20,518,224
# 19                                       Jim Jarmusch        $   1,971,135
#
#         runtime                      studio
# 0   104 minutes                         NaN
# 1   108 minutes           Entertainment One
# 2   116 minutes                         NaN
# 3   128 minutes                         NaN
# 4   200 minutes                         NaN
# 5    95 minutes       Warner Bros. Pictures
# 6    82 minutes          Paramount Pictures
# 7   123 minutes      Sony Pictures Classics
# 8   117 minutes                         NaN
# 9   108 minutes                         NaN
# 10          NaN                         NaN
# 11          NaN  Showtime Documentary Films
# 12   90 minutes       Seventh Art Releasing
# 13   97 minutes                         NaN
# 14  106 minutes                         NaN
# 15  108 minutes                ATO Pictures
# 16  129 minutes               Sony Pictures
# 17   98 minutes                         NaN
# 18  127 minutes          Universal Pictures
# 19   96 minutes                         MGM  >

# %%
rt_df.shape
# Out:
# (20, 10)

# %%
rt_df.dropna(axis=0, inplace=True)
rt_df
# Out:
#     id                                           synopsis rating  \
# 1    3  New York City, not-too-distant-future: Eric Pa...      R
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 15  22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 18  25  From ancient Japan's most enduring tale, the e...  PG-13
# 19  26  A comic series of short vignettes build on one...      R
#
#                                                 genre             director  \
# 1                   Drama|Science Fiction and Fantasy     David Cronenberg
# 6                                              Comedy          Jake Kasdan
# 7                                               Drama         Ray Lawrence
# 15                  Comedy|Drama|Mystery and Suspense  George Hickenlooper
# 18  Action and Adventure|Drama|Science Fiction and...     Carl Erik Rinsch
# 19  Art House and International|Comedy|Drama|Music...         Jim Jarmusch
#
#                               writer currency  box_office      runtime  \
# 1       David Cronenberg|Don DeLillo        $     600,000  108 minutes
# 6                         Mike White        $  41,032,915   82 minutes
# 7   Raymond Carver|Beatrix Christian        $     224,114  123 minutes
# 15                     Norman Snider        $   1,039,869  108 minutes
# 18        Chris Morgan|Hossein Amini        $  20,518,224  127 minutes
# 19                      Jim Jarmusch        $   1,971,135   96 minutes
#
#                     studio
# 1        Entertainment One
# 6       Paramount Pictures
# 7   Sony Pictures Classics
# 15            ATO Pictures
# 18      Universal Pictures
# 19                     MGM

# %% [markdown]
# Histogram showing the top rated movies in the box office

# %%
rt_df.box_office
# Out:
# 1        600,000
# 6     41,032,915
# 7        224,114
# 15     1,039,869
# 18    20,518,224
# 19     1,971,135
# Name: box_office, dtype: object

# %%
rt_df.studio
# Out:
# 1          Entertainment One
# 6         Paramount Pictures
# 7     Sony Pictures Classics
# 15              ATO Pictures
# 18        Universal Pictures
# 19                       MGM
# Name: studio, dtype: object

# %%
rt_df.synopsis
# Out:
# 1     New York City, not-too-distant-future: Eric Pa...
# 6     Some cast and crew from NBC's highly acclaimed...
# 7     Stewart Kane, an Irishman living in the Austra...
# 15    Two-time Academy Award Winner Kevin Spacey giv...
# 18    From ancient Japan's most enduring tale, the e...
# 19    A comic series of short vignettes build on one...
# Name: synopsis, dtype: object

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(x = rt_df['studio'], height= rt_df['box_office'])
ax.set_xlabel('studio')
ax.set_ylabel('box_office')
ax.set_title('Relationship between studio and box_office');

# %%
fig, ax = plt.subplots(figsize=(20,8))
plt.barh(rt_df['genre'], width= rt_df['box_office'])
ax.set_title('How the genre of movie perform in the box office')
ax.set_ylabel('genre')
ax.set_xlabel('box office');

# %%
rt_df.sort_values(by='box_office', ascending=False)
rt_df
# Out:
#     id                                           synopsis rating  \
# 1    3  New York City, not-too-distant-future: Eric Pa...      R
# 6   10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7   13  Stewart Kane, an Irishman living in the Austra...      R
# 15  22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 18  25  From ancient Japan's most enduring tale, the e...  PG-13
# 19  26  A comic series of short vignettes build on one...      R
#
#                                                 genre             director  \
# 1                   Drama|Science Fiction and Fantasy     David Cronenberg
# 6                                              Comedy          Jake Kasdan
# 7                                               Drama         Ray Lawrence
# 15                  Comedy|Drama|Mystery and Suspense  George Hickenlooper
# 18  Action and Adventure|Drama|Science Fiction and...     Carl Erik Rinsch
# 19  Art House and International|Comedy|Drama|Music...         Jim Jarmusch
#
#                               writer currency  box_office      runtime  \
# 1       David Cronenberg|Don DeLillo        $     600,000  108 minutes
# 6                         Mike White        $  41,032,915   82 minutes
# 7   Raymond Carver|Beatrix Christian        $     224,114  123 minutes
# 15                     Norman Snider        $   1,039,869  108 minutes
# 18        Chris Morgan|Hossein Amini        $  20,518,224  127 minutes
# 19                      Jim Jarmusch        $   1,971,135   96 minutes
#
#                     studio
# 1        Entertainment One
# 6       Paramount Pictures
# 7   Sony Pictures Classics
# 15            ATO Pictures
# 18      Universal Pictures
# 19                     MGM

# %%
rt_df.runtime
# Out:
# 1     108 minutes
# 6      82 minutes
# 7     123 minutes
# 15    108 minutes
# 18    127 minutes
# 19     96 minutes
# Name: runtime, dtype: object

# %% [markdown]
# Bar graph of relationship between runtime and box office revenues

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(x = rt_df['runtime'], height= rt_df['box_office'])
ax.set_xlabel('runtime')
ax.set_ylabel('box office in millions')
ax.set_title('Relationship between runtime and box_office');

# %% [markdown]
# Most sort after producer

# %%
rt_df.writer.value_counts()
# Out:
# David Cronenberg|Don DeLillo        1
# Mike White                          1
# Raymond Carver|Beatrix Christian    1
# Norman Snider                       1
# Chris Morgan|Hossein Amini          1
# Jim Jarmusch                        1
# Name: writer, dtype: int64

# %%
rt_df.director.value_counts()
# Out:
# David Cronenberg       1
# Jake Kasdan            1
# Ray Lawrence           1
# George Hickenlooper    1
# Carl Erik Rinsch       1
# Jim Jarmusch           1
# Name: director, dtype: int64

# %% [markdown]
# scatter plot to show the relationship between movie producing studio and revenues at the box ofice

# %%
rt_df.plot.scatter(x='studio', y='box_office')
plt.title('Relationship between Studio and Box office')
plt.xlabel('studio')
plt.ylabel('box_office')
plt.show()

# %%
rt_df = pd.read_csv('rt.reviews.tsv.gz',delimiter='\t' )
rt_df
